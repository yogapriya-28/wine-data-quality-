# %%
import pandas as pd
import numpy as np

# %%
 # loading the dataset
df = pd.read_csv('/content/Wine_Quality_Data.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
a=OrdinalEncoder()
df['color']=a.fit_transform(df[['color']])
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# checking for null values
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 660.0 KB

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# #**Data Preprocessing**

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df['quality'] = df['quality'].apply(lambda x: 1 if x >= 7 else 0)
df.rename(columns={'quality': 'good-quality'}, inplace=True)
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  good-quality  color
# 0      9.4             0    0.0
# ...

# %% [markdown]
# #**Exploratory Data Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='good-quality', data=df)
plt.xlabel('Good Quality')
plt.ylabel('Count')
plt.title('Count of Good vs Bad Quality Wines')
plt.show()

# %%
sns.countplot(x="color", hue="good-quality", data=df)
plt.title('Color vs Quality Wines')
plt.show()

# %%
#it’s probably categorical (like "red", "white", etc.).

#But df.corr() only works with numeric columns.

#Pandas converts categorical values (like "red", "white")

#But these correlations are misleading.

#Since "color" is categorical, the numeric codes don’t represent real numeric distances.

#So the correlation values involving "color" aren’t meaningful.

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df= df.drop(columns=['color'])

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# good-quality              -0.049447         -0.151714     0.054444
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
#Analysis of correlation between features

df.corr()['good-quality'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(20,20))

sns.scatterplot(x='fixed_acidity', y='citric_acid', hue='good-quality', data=df, ax=ax[0,0])
sns.scatterplot(x='volatile_acidity', y='citric_acid', hue='good-quality', data=df, ax=ax[0,1])
sns.scatterplot(x='free_sulfur_dioxide', y='total_sulfur_dioxide', hue='good-quality', data=df, ax=ax[0,2])
sns.scatterplot(x='fixed_acidity', y='density', hue='good-quality', data=df, ax=ax[0,3])

sns.scatterplot(x='fixed_acidity', y='pH', hue='good-quality', data=df, ax=ax[1,0])
sns.scatterplot(x='citric_acid', y='pH', hue='good-quality', data=df, ax=ax[1,1])
sns.scatterplot(x='chlorides', y='sulphates', hue='good-quality', data=df, ax=ax[1,2])
sns.scatterplot(x='residual_sugar', y='alcohol', hue='good-quality', data=df, ax=ax[1,3])

plt.tight_layout()
plt.show()

# %% [markdown]
# #**Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('good-quality', axis=1)
y = df['good-quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4547, 11), (1950, 11), (4547,), (1950,))

# %%
y_test.value_counts()
# Out:
# good-quality
# 0    1585
# 1     365
# Name: count, dtype: int64

# %% [markdown]
# #**Scaling**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #**SMOTE**

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

# Check new class distribution
print("Before SMOTE:\n", pd.Series(y_train).value_counts())
print("After SMOTE:\n", pd.Series(y_train_res).value_counts())
# Out:
# Before SMOTE:
#  good-quality
# 0    3635
# 1     912
# Name: count, dtype: int64
# After SMOTE:
#  good-quality
# 0    3635
# 1    3635
# Name: count, dtype: int64

# %% [markdown]
# #**Model Training**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# #**Random forest**

# %%
rf=RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    min_samples_split=5,
    min_impurity_decrease=0.001,
    random_state=42
)

# %%
#training the model
rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 0.8673850890697163

# %%
# testing the model
rf_pred = rf.predict(X_test)
accuracy_score(y_test, rf_pred)
# Out:
# 0.8441025641025641

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1585
#            1       0.69      0.30      0.42       365
#
#     accuracy                           0.84      1950
#    macro avg       0.77      0.64      0.67      1950
# weighted avg       0.83      0.84      0.82      1950

# %% [markdown]
# #**Decision Tree**

# %%
tr = DecisionTreeClassifier()
tr
# Out:
# DecisionTreeClassifier()

# %%
tr = DecisionTreeClassifier(
    min_samples_split=5,
    min_impurity_decrease=0.001,
    random_state=42
)

# %%
#training the model
tr.fit(X_train, y_train)
tr.score(X_train, y_train)
# Out:
# 0.8557290521222785

# %%
# testing the model
tr_pred = tr.predict(X_test)
accuracy_score(y_test, tr_pred)
# Out:
# 0.8317948717948718

# %%
print(classification_report(y_test, tr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      1585
#            1       0.57      0.44      0.49       365
#
#     accuracy                           0.83      1950
#    macro avg       0.72      0.68      0.70      1950
# weighted avg       0.82      0.83      0.82      1950

# %% [markdown]
# #**K-Nearest Neighbors (KNN)**

# %%
kn=KNeighborsClassifier(n_neighbors=5)
kn
# Out:
# KNeighborsClassifier()

# %%
#training the model
kn.fit(X_train, y_train)
kn.score(X_train, y_train)
# Out:
# 0.8592478557290522

# %%
# testing the model
kn_pred = kn.predict(X_test)
accuracy_score(y_test, kn_pred)
# Out:
# 0.8035897435897436

# %%
print(classification_report(y_test, kn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1585
#            1       0.47      0.34      0.39       365
#
#     accuracy                           0.80      1950
#    macro avg       0.66      0.62      0.64      1950
# weighted avg       0.78      0.80      0.79      1950

# %% [markdown]
# #**Support Vector Machine (SVM)**

# %%
sv = SVC(kernel='rbf')
sv
# Out:
# SVC()

# %%
#training the model
sv.fit(X_train, y_train)
sv.score(X_train, y_train)
# Out:
# 0.7994281944138992

# %%
# testing the model
sv_pred = sv.predict(X_test)
accuracy_score(y_test, sv_pred)
# Out:
# 0.8128205128205128

# %%
print(classification_report(y_test, sv_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      1585
#            1       0.00      0.00      0.00       365
#
#     accuracy                           0.81      1950
#    macro avg       0.41      0.50      0.45      1950
# weighted avg       0.66      0.81      0.73      1950
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #**Logistic Regression**

# %%
lr = LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
#training the model
lr.fit(X_train, y_train)
lr.score(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.809764680008797

# %%
# testing the model
lr_pred = lr.predict(X_test)
accuracy_score(y_test, lr_pred)
# Out:
# 0.8143589743589743

# %%
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      1585
#            1       0.51      0.19      0.28       365
#
#     accuracy                           0.81      1950
#    macro avg       0.67      0.57      0.59      1950
# weighted avg       0.78      0.81      0.78      1950

# %% [markdown]
# #**Model Evaluation**

# %% [markdown]
# #**Random forest**

# %%
# Assuming your Random Forest predictions are stored in rf_pred
print('Random Forest Model Accuracy: ', accuracy_score(y_test, rf_pred))
print('Random Forest Model F1 score: ', metrics.f1_score(y_test, rf_pred))
print('Random Forest Model MAE: ', metrics.mean_absolute_error(y_test, rf_pred))
print('Random Forest Model RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, rf_pred)))
# Out:
# Random Forest Model Accuracy:  0.8815384615384615
# Random Forest Model F1 score:  0.6362204724409449
# Random Forest Model MAE:  0.11846153846153847
# Random Forest Model RMSE:  0.34418242032610913

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier().fit(X_train,y_train)
rf_pred=model.predict(X_test)
rf_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,rf_pred)
# Out:
# array([[1517,   68],
#        [ 163,  202]])

# %%
sns.heatmap(confusion_matrix(y_test,rf_pred), annot=True, fmt='d',  cmap='Reds')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Random forest')
plt.show()

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      1585
#            1       0.75      0.55      0.64       365
#
#     accuracy                           0.88      1950
#    macro avg       0.83      0.76      0.78      1950
# weighted avg       0.87      0.88      0.87      1950

# %% [markdown]
# #**Decision Tree**

# %%
print('Decision Tree Model Accuracy: ', accuracy_score(y_test, tr_pred))
print('Decision Tree Model f1 score: ', metrics.f1_score(y_test, tr_pred))
print('Decision Tree Model MAE: ', metrics.mean_absolute_error(y_test, tr_pred))
print('Decision Tree Model RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, tr_pred)))
# Out:
# Decision Tree Model Accuracy:  0.8317948717948718
# Decision Tree Model f1 score:  0.49226006191950467
# Decision Tree Model MAE:  0.1682051282051282
# Decision Tree Model RMSE:  0.4101281850898914

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier().fit(X_train,y_train)
tr_pred=model.predict(X_test)
tr_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,tr_pred)
# Out:
# array([[1408,  177],
#        [ 143,  222]])

# %%
sns.heatmap(confusion_matrix(y_test,tr_pred), annot=True, fmt='d',cmap='Greens')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
print(classification_report(y_test, tr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      1585
#            1       0.56      0.61      0.58       365
#
#     accuracy                           0.84      1950
#    macro avg       0.73      0.75      0.74      1950
# weighted avg       0.84      0.84      0.84      1950

# %% [markdown]
# #**K-Nearest Neighbors (KNN)**

# %%
print('K-Nearest Neighbors Model Accuracy: ', accuracy_score(y_test, kn_pred))
print('K-Nearest Neighbors Model f1 score: ', metrics.f1_score(y_test, kn_pred))
print('K-Nearest Neighbors Model MAE: ', metrics.mean_absolute_error(y_test, kn_pred))
print('K-Nearest Neighbors Model RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, kn_pred)))
# Out:
# K-Nearest Neighbors Model Accuracy:  0.8035897435897436
# K-Nearest Neighbors Model f1 score:  0.39109697933227344
# K-Nearest Neighbors Model MAE:  0.19641025641025642
# K-Nearest Neighbors Model RMSE:  0.4431819676050193

# %%
from sklearn.neighbors import KNeighborsClassifier
model= KNeighborsClassifier().fit(X_train,y_train)
kn_pred=model.predict(X_test)
kn_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,kn_pred)
# Out:
# array([[1444,  141],
#        [ 242,  123]])

# %%
sns.heatmap(confusion_matrix(y_test, kn_pred), annot=True, fmt='d',cmap='Purples')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for K-Nearest Neighbors')
plt.show()

# %%
print(classification_report(y_test, kn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1585
#            1       0.47      0.34      0.39       365
#
#     accuracy                           0.80      1950
#    macro avg       0.66      0.62      0.64      1950
# weighted avg       0.78      0.80      0.79      1950

# %% [markdown]
# #**Support Vector Machine (SVM)**

# %%
print('Support Vector Machine Model Accuracy: ', accuracy_score(y_test, sv_pred))
print('Support Vector Machine Model f1 score: ', metrics.f1_score(y_test, sv_pred))
print('Support Vector Machine Model MAE: ', metrics.mean_absolute_error(y_test, sv_pred))
print('Support Vector Machine Model RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, sv_pred)))
# Out:
# Support Vector Machine Model Accuracy:  0.8128205128205128
# Support Vector Machine Model f1 score:  0.0
# Support Vector Machine Model MAE:  0.18717948717948718
# Support Vector Machine Model RMSE:  0.43264244726966766

# %%
from sklearn.svm import SVC
model= SVC().fit(X_train,y_train)
sv_pred=model.predict(X_test)
sv_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,sv_pred)
# Out:
# array([[1585,    0],
#        [ 365,    0]])

# %%
sns.heatmap(confusion_matrix(y_test, sv_pred), annot=True, fmt='d',cmap='Blues')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Support Vector Machine')
plt.show()

# %%
print(classification_report(y_test, sv_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      1585
#            1       0.00      0.00      0.00       365
#
#     accuracy                           0.81      1950
#    macro avg       0.41      0.50      0.45      1950
# weighted avg       0.66      0.81      0.73      1950
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #**Logistic Regression**

# %%
print('Logistic Regression Model Accuracy: ', accuracy_score(y_test, lr_pred))
print('Logistic Regression Model f1 score: ', metrics.f1_score(y_test, lr_pred))
print('Logistic Regression Model MAE: ', metrics.mean_absolute_error(y_test, lr_pred))
print('Logistic Regression Model RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, lr_pred)))
# Out:
# Logistic Regression Model Accuracy:  0.8143589743589743
# Logistic Regression Model f1 score:  0.2788844621513944
# Logistic Regression Model MAE:  0.18564102564102564
# Logistic Regression Model RMSE:  0.4308607961291276

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression().fit(X_train,y_train)
lr_pred=model.predict(X_test)
lr_pred
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([1, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,lr_pred)
# Out:
# array([[1518,   67],
#        [ 295,   70]])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,lr_pred)
# Out:
# array([[1518,   67],
#        [ 295,   70]])

# %%
sns.heatmap(confusion_matrix(y_test, lr_pred), annot=True, fmt='d',cmap='Greens')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      1585
#            1       0.51      0.19      0.28       365
#
#     accuracy                           0.81      1950
#    macro avg       0.67      0.57      0.59      1950
# weighted avg       0.78      0.81      0.78      1950

# %% [markdown]
# #**Model comparison**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

models = [ 'K-Nearest Neighbors','Logistic Regression', 'Support Vector Machine', 'Decision Tree','Random Forest']
accuracy = [
    accuracy_score(y_test, kn_pred),
    accuracy_score(y_test, lr_pred),
    accuracy_score(y_test, sv_pred),
    accuracy_score(y_test, tr_pred),
    accuracy_score(y_test, rf_pred)
]

plt.figure(figsize=(10,6))
colors = sns.color_palette("Set2", len(models))  # different colors
ax = sns.barplot(x=models, y=accuracy, palette=colors)

# Add values on top
for i, v in enumerate(accuracy):
    ax.text(i, v + 0.01, f"{v:.2f}", ha='center', fontweight='bold')

plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0.7, 1.0)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4137779421.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=models, y=accuracy, palette=colors)

# %% [markdown]
# #**Conclusion**
# It is observed that the Random forest model performs the best on the test set with an accuracy of 88.15%. The model can predict the quality of the wine based on the given features with an accuracy of 88.15%
